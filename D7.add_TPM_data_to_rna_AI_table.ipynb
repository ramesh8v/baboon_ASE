# %%
import numpy as np
import pandas as pd
from glob import glob

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
# pandarallel.initialize(progress_bar=True, nb_workers=8)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read concatenated TPM table

# %%
df = pd.read_csv("../../rsem/gene_tpm_counts.tsv", sep="\t")

# %%
df.head(3)
# Out:
#   gene_id                                   transcript_id(s)   length  \
# 0    A1BG                      XM_003916257.5,XM_009195529.4  2862.61
# 1    A1CF  XM_003903944.5,XM_009214926.4,XM_031652209.1,X...  4138.25
# 2   A2ML1                                     XM_031650266.1  5656.00
#
#    effective_length  expected_count   TPM  FPKM    sample
# 0           2655.86           52.00  1.92  1.00  HIP_ZT12
# 1           3931.50            0.00  0.00  0.00  HIP_ZT12
# 2           5449.25           18.53  0.33  0.17  HIP_ZT12

# %%
df['timepoint'] = df['sample'].apply(lambda x: x.split('_')[1])
df['tissue'] = df['sample'].apply(lambda x: x.split('_')[0])

# %%
df.head(3)
# Out:
#   gene_id                                   transcript_id(s)   length  \
# 0    A1BG                      XM_003916257.5,XM_009195529.4  2862.61
# 1    A1CF  XM_003903944.5,XM_009214926.4,XM_031652209.1,X...  4138.25
# 2   A2ML1                                     XM_031650266.1  5656.00
#
#    effective_length  expected_count   TPM  FPKM    sample timepoint tissue
# 0           2655.86           52.00  1.92  1.00  HIP_ZT12      ZT12    HIP
# 1           3931.50            0.00  0.00  0.00  HIP_ZT12      ZT12    HIP
# 2           5449.25           18.53  0.33  0.17  HIP_ZT12      ZT12    HIP

# %% [markdown]
# #### Read RNA AI table

# %%
rna = pd.read_parquet("./data_files/concatenated_data/gatk_all_samples_concatenated_annt_added_multiline_dupes_dropped_phase_added.parquet")

# %%
rna.head(2)
# Out:
#   tissue timepoint              loci  refCount  altCount  totalCount  \
# 0    HIP       ZT0   NC_044976.1:204         1        17          18
# 1    HIP       ZT0  NC_044976.1:4126         1         0           1
#
#     refBias  binomTest       fdr REF  ... ANN[*].GENE ANN[*].FEATURE  \
# 0  0.055556   0.000145  0.012577   T  ...           .              .
# 1  1.000000   1.000000  1.000000   G  ...           .              .
#
#   ANN[*].BIOTYPE                     uq_id      phase_info  \
# 0              .   HIP:ZT0:NC_044976.1:204     GT:AD:DP:GQ
# 1              .  HIP:ZT0:NC_044976.1:4126  GT:AD:DP:GQ:PS
#
#              phase_dat   is_phased    phase_id homologBias ai_type
# 0   0/1:350,158:509:99  not_phased  not_phased         NaN      MA
# 1  1|0:19,17:36:99:204      phased         204         0.0   no_ai
#
# [2 rows x 24 columns]

# %%
def categorize_SNV(x):
    if x['totalCount'] <=5:
        return "LT5_reads"
    elif x['binomTest'] >= 0.05:
        return "binom_failed"
    elif x['fdr'] >= 0.05:
        return "fdr_failed"
    else:
        return x['ai_type']

# %%
rna['ai_cat'] = rna.progress_apply(categorize_SNV, axis=1)
# Out:
#   0%|          | 0/47889413 [00:00<?, ?it/s]

# %%
rna = rna.merge(df[['timepoint', 'tissue', 'gene_id', 'TPM', 'FPKM']],
                left_on=['timepoint', 'tissue', 'ANN[*].GENE'],
                right_on=['timepoint', 'tissue', 'gene_id'], how='left')

# %%
rna.head(20)
# Out:
#    tissue timepoint               loci  refCount  altCount  totalCount  \
# 0     HIP       ZT0    NC_044976.1:204         1        17          18
# 1     HIP       ZT0   NC_044976.1:4126         1         0           1
# 2     HIP       ZT0   NC_044976.1:4522         0         1           1
# 3     HIP       ZT0   NC_044976.1:6729        39        27          66
# 4     HIP       ZT0   NC_044976.1:6871        55        53         108
# 5     HIP       ZT0   NC_044976.1:7352        23        19          42
# 6     HIP       ZT0   NC_044976.1:7697        36        31          67
# 7     HIP       ZT0   NC_044976.1:7897        28        32          60
# 8     HIP       ZT0  NC_044976.1:10272         0         1           1
# 9     HIP       ZT0  NC_044976.1:11794         1         4           5
# 10    HIP       ZT0  NC_044976.1:11807         4         1           5
# 11    HIP       ZT0  NC_044976.1:12400         9         3          12
# 12    HIP       ZT0  NC_044976.1:13800         3         4           7
# 13    HIP       ZT0  NC_044976.1:15186         1         0           1
# 14    HIP       ZT0  NC_044976.1:18152         1         1           2
# 15    HIP       ZT0  NC_044976.1:18152         1         1           2
# 16    HIP       ZT0  NC_044976.1:18340         1         2           3
# 17    HIP       ZT0  NC_044976.1:18340         1         2           3
# 18    HIP       ZT0  NC_044976.1:19585         1         0           1
# 19    HIP       ZT0  NC_044976.1:20427         1         0           1
#
#      refBias  binomTest       fdr REF  ...      phase_info  \
# 0   0.055556   0.000145  0.012577   T  ...     GT:AD:DP:GQ
# 1   1.000000   1.000000  1.000000   G  ...  GT:AD:DP:GQ:PS
# 2   0.000000   1.000000  1.000000   G  ...  GT:AD:DP:GQ:PS
# 3   0.590909   0.175286  1.000000   C  ...  GT:AD:DP:GQ:PS
# 4   0.509259   0.923401  1.000000   G  ...  GT:AD:DP:GQ:PS
# 5   0.547619   0.643969  1.000000   A  ...  GT:AD:DP:GQ:PS
# 6   0.537313   0.625407  1.000000   A  ...  GT:AD:DP:GQ:PS
# 7   0.466667   0.698883  1.000000   T  ...  GT:AD:DP:GQ:PS
# 8   0.000000   1.000000  1.000000   G  ...  GT:AD:DP:GQ:PS
# 9   0.200000   0.375000  1.000000   G  ...  GT:AD:DP:GQ:PS
# 10  0.800000   0.375000  1.000000   C  ...  GT:AD:DP:GQ:PS
# 11  0.750000   0.145996  1.000000   C  ...  GT:AD:DP:GQ:PS
# 12  0.428571   1.000000  1.000000   A  ...  GT:AD:DP:GQ:PS
# 13  1.000000   1.000000  1.000000   A  ...  GT:AD:DP:GQ:PS
# 14  0.500000   1.000000  1.000000   C  ...  GT:AD:DP:GQ:PS
# 15  0.500000   1.000000  1.000000   C  ...  GT:AD:DP:GQ:PS
# 16  0.333333   1.000000  1.000000   G  ...  GT:AD:DP:GQ:PS
# 17  0.333333   1.000000  1.000000   G  ...  GT:AD:DP:GQ:PS
# 18  1.000000   1.000000  1.000000   G  ...  GT:AD:DP:GQ:PS
# 19  1.000000   1.000000  1.000000   A  ...  GT:AD:DP:GQ:PS
#
#               phase_dat   is_phased    phase_id homologBias ai_type  \
# 0    0/1:350,158:509:99  not_phased  not_phased         NaN      MA
# 1   1|0:19,17:36:99:204      phased         204    0.000000   no_ai
# 2   1|0:27,13:40:99:204      phased         204    1.000000   no_ai
# 3   1|0:18,18:36:99:204      phased         204    0.409091   no_ai
# 4   1|0:22,21:44:99:204      phased         204    0.490741   no_ai
# 5   0|1:14,20:35:99:204      phased         204    0.547619   no_ai
# 6   0|1:15,18:33:99:204      phased         204    0.537313   no_ai
# 7   0|1:15,22:37:99:204      phased         204    0.466667   no_ai
# 8   0|1:19,27:47:99:204      phased         204    0.000000   no_ai
# 9   1|0:22,13:36:99:204      phased         204    0.800000   no_ai
# 10  0|1:15,21:38:99:204      phased         204    0.800000   no_ai
# 11  0|1:26,25:51:99:204      phased         204    0.750000   no_ai
# 12  1|0:15,16:31:99:204      phased         204    0.571429   no_ai
# 13  1|0:20,19:39:99:204      phased         204    0.000000   no_ai
# 14  1|0:26,20:46:99:204      phased         204    0.500000   no_ai
# 15  1|0:26,20:46:99:204      phased         204    0.500000   no_ai
# 16  1|0:14,18:36:99:204      phased         204    0.666667   no_ai
# 17  1|0:14,18:36:99:204      phased         204    0.666667   no_ai
# 18  1|0:20,25:49:99:204      phased         204    0.000000   no_ai
# 19  1|0:21,24:46:99:204      phased         204    0.000000   no_ai
#
#           ai_cat  gene_id   TPM  FPKM
# 0             MA      NaN   NaN   NaN
# 1      LT5_reads      NaN   NaN   NaN
# 2      LT5_reads      NaN   NaN   NaN
# 3   binom_failed      NaN   NaN   NaN
# 4   binom_failed      NaN   NaN   NaN
# 5   binom_failed      NaN   NaN   NaN
# 6   binom_failed      NaN   NaN   NaN
# 7   binom_failed      NaN   NaN   NaN
# 8      LT5_reads  TMEM88B  3.55  1.95
# 9      LT5_reads      NaN   NaN   NaN
# 10     LT5_reads      NaN   NaN   NaN
# 11  binom_failed      NaN   NaN   NaN
# 12  binom_failed  ANKRD65  2.50  1.37
# 13     LT5_reads  ANKRD65  2.50  1.37
# 14     LT5_reads  ANKRD65  2.50  1.37
# 15     LT5_reads  ANKRD65  2.50  1.37
# 16     LT5_reads  ANKRD65  2.50  1.37
# 17     LT5_reads  ANKRD65  2.50  1.37
# 18     LT5_reads  ANKRD65  2.50  1.37
# 19     LT5_reads  ANKRD65  2.50  1.37
#
# [20 rows x 28 columns]

# %%
rna.to_parquet("./data_files/concatenated_data/gatk_all_samples_concatenated_annt_added_multiline_dupes_dropped_phase_added_with_TPM.parquet")

# %% [markdown]
# ### categorize TPMs and FPKMs

# %%
### read the written file, since it's written in the previous cell
rna = pd.read_parquet("./data_files/concatenated_data/gatk_all_samples_concatenated_annt_added_multiline_dupes_dropped_phase_added_with_TPM.parquet")

# %%
rna.head(2)
# Out:
#   tissue timepoint              loci  refCount  altCount  totalCount  \
# 0    HIP       ZT0   NC_044976.1:204         1        17          18
# 1    HIP       ZT0  NC_044976.1:4126         1         0           1
#
#     refBias  binomTest       fdr REF  ...      phase_info  \
# 0  0.055556   0.000145  0.012577   T  ...     GT:AD:DP:GQ
# 1  1.000000   1.000000  1.000000   G  ...  GT:AD:DP:GQ:PS
#
#              phase_dat   is_phased    phase_id homologBias ai_type     ai_cat  \
# 0   0/1:350,158:509:99  not_phased  not_phased         NaN      MA         MA
# 1  1|0:19,17:36:99:204      phased         204         0.0   no_ai  LT5_reads
#
#   gene_id TPM FPKM
# 0    None NaN  NaN
# 1    None NaN  NaN
#
# [2 rows x 28 columns]

# %%
def categorize_PMs(x):
    if x <= 0.5:
        return "LT0.5"
    elif x <= 10:
        return "low"
    elif x <= 1000:
        return "medium"
    else:
        return "high"

# %%
rna['TPM_cat'] = rna['TPM'].progress_apply(categorize_PMs)
# Out:
#   0%|          | 0/47889413 [00:00<?, ?it/s]

# %%
rna['FPKM_cat'] = rna['FPKM'].progress_apply(categorize_PMs)
# Out:
#   0%|          | 0/47889413 [00:00<?, ?it/s]

# %%
rna['TPM_cat'].value_counts(), rna['FPKM_cat'].value_counts()
# Out:
# (medium    20708083
#  low       14170626
#  high       9292553
#  LT0.5      3718151
#  Name: TPM_cat, dtype: int64,
#  low       17431080
#  medium    16875389
#  high       9231193
#  LT0.5      4351751
#  Name: FPKM_cat, dtype: int64)

# %%
rna.to_parquet("./data_files/concatenated_data/gatk_all_samples_concatenated_annt_added_multiline_dupes_dropped_phase_added_with_TPM.parquet")
