# %%
# imports
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from pandarallel import pandarallel

# %%
tqdm.pandas()
import warnings
warnings.filterwarnings("ignore")
pandarallel.initialize(progress_bar=True, nb_workers=8)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
### declare constants
TIMEPOINTS = [f'ZT{i}' for i in range(0,23) if i%2==0]
TIMEPOINTS
# Out:
# ['ZT0',
#  'ZT2',
#  'ZT4',
#  'ZT6',
#  'ZT8',
#  'ZT10',
#  'ZT12',
#  'ZT14',
#  'ZT16',
#  'ZT18',
#  'ZT20',
#  'ZT22']

# %%
df = pd.read_parquet("./data_files/concatenated_data/gatk_all_samples_concatenated_annt_added_multiline_dupes_dropped.parquet")

# %%
df.head(3)
# Out:
#   tissue timepoint              loci  refCount  altCount  totalCount  \
# 0    HIP       ZT0   NC_044976.1:204         1        17          18
# 1    HIP       ZT0  NC_044976.1:4126         1         0           1
# 2    HIP       ZT0  NC_044976.1:4522         0         1           1
#
#     refBias  binomTest       fdr REF ALT ANN[*].ALLELE ANN[*].EFFECT  \
# 0  0.055556   0.000145  0.012577   T   A             .             .
# 1  1.000000   1.000000  1.000000   G   A             .             .
# 2  0.000000   1.000000  1.000000   G   A             .             .
#
#   ANN[*].IMPACT ANN[*].GENE ANN[*].FEATURE ANN[*].BIOTYPE
# 0             .           .              .              .
# 1             .           .              .              .
# 2             .           .              .              .

# %%
df['refBias'] = df['refBias'].astype(float)

# %%
df['uq_id'] = df['tissue'] + ":" + df['timepoint'] + ":" + df['loci']

# %%
df.shape
# Out:
# (47889413, 18)

# %%
## read snpeff vcf file, create a dataframe, merge with AI file
for tp in TIMEPOINTS:
    print(tp)
    phase_dat = pd.read_csv(f"../../wasp_rerun_june22/data_files/vcfs_annotated_with_snpeff_all/{tp}_snpeff.vcf", sep="\t", comment="#", header=None)
    phase_dat['loci'] = phase_dat[0] + ":" + phase_dat[1].astype(str)
    phase_dat = phase_dat[['loci', 8, 9]]
    phase_dat.columns = ['loci', 'phase_info', 'phase_dat']
    tmp = df[df['timepoint']==tp].merge(phase_dat, on='loci', how='left')
    if tp == "ZT0":
        dat = tmp
    else:
        dat = dat.append(tmp)
# Out:
# ZT0
# ZT2
# ZT4
# ZT6
# ZT8
# ZT10
# ZT12
# ZT14
# ZT16
# ZT18
# ZT20
# ZT22

# %%
dat.sample(50)
# Out:
#         tissue timepoint                   loci  refCount  altCount  \
# 465047     VIC      ZT16   NC_044993.1:66599840         0         1
# 569331     HEA       ZT8     NC_044988.1:132065         2         1
# 4130166    KIC      ZT18   NC_044994.1:66356799         0         1
# 2632912    ILE       ZT8  NC_044981.1:126429485         0         1
# 3159509    ILE      ZT14  NC_044982.1:125448073         2         2
# 44416      SPL      ZT18  NC_044976.1:204452726         2         1
# 3296803    ILE      ZT10   NC_044976.1:25997598         2         3
# 1863842    VIC       ZT0   NC_044989.1:61802274         1         0
# 4052749    VIC      ZT22   NC_044989.1:10612341         5         3
# 3562254    LUN       ZT8  NC_044987.1:107667494         6         3
# 1119047    SPL       ZT6    NC_044995.1:7066261       104        47
# 3212662    THA       ZT6   NC_044986.1:39513814         0         1
# 2481419    WAT      ZT18   NC_044986.1:14229205         6         2
# 1816534    VIC       ZT2    NC_044976.1:4878202         0         1
# 519898     KIC      ZT20   NC_044980.1:13848677         1         0
# 1593452    WAT      ZT22   NC_044995.1:23427593         0         2
# 973503     ILE      ZT20  NC_044981.1:164488731         5         2
# 225809     VIC       ZT4   NC_044983.1:26988603         2         0
# 2203859    PAN       ZT6    NC_044992.1:6995089         1         0
# 3230989    SPL       ZT8   NC_044992.1:59630242         0         1
# 3885006    LUN       ZT4   NC_044980.1:35001492        52        53
# 495777     HIP      ZT22   NC_044986.1:35705885         2         0
# 481853     SPL      ZT18   NC_044990.1:88628431         0         3
# 2405964    KIC      ZT14  NC_044987.1:121845906         1         0
# 529606     WAT       ZT2  NC_044980.1:173782140         0         5
# 2604441    ILE       ZT8   NC_044980.1:88509126         1         0
# 259048     VIC       ZT4   NC_044984.1:56411373         0         2
# 1913041    WAT      ZT14   NC_044987.1:76693707         0         2
# 2253257    KIC      ZT14   NC_044979.1:66486526         0         1
# 3117727    HEA       ZT0       NC_020006.2:7652        69         0
# 3140888    SPL       ZT8   NC_044987.1:13012583         3         0
# 367555     SPL      ZT14     NC_044990.1:377689         4         3
# 3641510    WAT       ZT0   NC_044979.1:92305515         0         1
# 2293143    HEA      ZT10   NC_044993.1:46223788        37        55
# 4034836    THA      ZT12   NC_044987.1:59001947        26        26
# 1239734    VIC       ZT6  NC_044978.1:133722727         1         1
# 4187300    THA      ZT12   NW_022164175.1:39696         2         2
# 550503     KIC      ZT20   NC_044981.1:74497533         1         0
# 3196486    ILE      ZT12   NC_044987.1:20061296         4         1
# 2825721    THA      ZT18   NC_044982.1:49229481         5         2
# 1342249    HEA      ZT12    NC_044990.1:6559501         0         1
# 2830545    KIC       ZT4  NC_044976.1:114303880         1         0
# 1056991    SPL       ZT6   NC_044991.1:57030821         9        10
# 2647263    KIC      ZT12   NC_044986.1:33049302         2         1
# 184537     SPL      ZT14  NC_044981.1:135358416         2         0
# 2167797    LUN       ZT0   NC_044980.1:35052408         1         0
# 2338601    SPL       ZT4   NC_044993.1:63193791         2         0
# 1552875    VIC       ZT6   NC_044992.1:59012420         1         0
# 1106380    SPL       ZT6    NC_044994.1:1463851         1         0
# 3588076    LUN       ZT8   NC_044990.1:90872870         2         0
#
#          totalCount   refBias     binomTest           fdr REF ALT  \
# 465047            1  0.000000  1.000000e+00  1.000000e+00   G   A
# 569331            3  0.666667  1.000000e+00  1.000000e+00   A   G
# 4130166           1  0.000000  1.000000e+00  1.000000e+00   A   G
# 2632912           1  0.000000  1.000000e+00  1.000000e+00   G   C
# 3159509           4  0.500000  1.000000e+00  1.000000e+00   G   A
# 44416             3  0.666667  1.000000e+00  1.000000e+00   T   C
# 3296803           5  0.400000  1.000000e+00  1.000000e+00   T   G
# 1863842           1  1.000000  1.000000e+00  1.000000e+00   A   G
# 4052749           8  0.625000  7.265625e-01  1.000000e+00   C   T
# 44416               .                                   .             .
# 3296803             G                      intron_variant      MODIFIER
# 1863842             G                      intron_variant      MODIFIER
# 4052749             T                      intron_variant      MODIFIER
# 3562254             A                      intron_variant      MODIFIER
# 1119047             T                  synonymous_variant           LOW
# 3212662             G                      intron_variant      MODIFIER
# 2481419             .                                   .             .
# 1816534             G                      intron_variant      MODIFIER
# 519898              G                      intron_variant      MODIFIER
# 1593452             A                      intron_variant      MODIFIER
# 973503              G                      intron_variant      MODIFIER
# 225809              A                      intron_variant      MODIFIER
# 2203859             A                      intron_variant      MODIFIER
# 3230989             C                      intron_variant      MODIFIER
# 3885006             G                  synonymous_variant           LOW
# 495777              C                      intron_variant      MODIFIER
# 481853              A                      intron_variant      MODIFIER
# 2405964             T                      intron_variant      MODIFIER
# 529606              T                      intron_variant      MODIFIER
# 2604441             T                      intron_variant      MODIFIER
# 259048              A                      intron_variant      MODIFIER
# 1913041             G                      intron_variant      MODIFIER
# 2253257             G                      intron_variant      MODIFIER
# 3117727             A                  synonymous_variant           LOW
# 3140888             C                      intron_variant      MODIFIER
# 367555              G                      intron_variant      MODIFIER
# 3641510             T                      intron_variant      MODIFIER
# 2293143             C                  synonymous_variant           LOW
# 4034836             T                  synonymous_variant           LOW
# 1239734             A                      intron_variant      MODIFIER
# 4187300             C                 3_prime_UTR_variant      MODIFIER
# 550503              A                      intron_variant      MODIFIER
# 3196486             C                      intron_variant      MODIFIER
# 2825721             T                      intron_variant      MODIFIER
# 1342249             .                                   .             .
# 2830545             A                      intron_variant      MODIFIER
# 1056991             A                      intron_variant      MODIFIER
# 2647263             A                      intron_variant      MODIFIER
# 184537              G                 5_prime_UTR_variant      MODIFIER
# 2167797             T                      intron_variant      MODIFIER
# 2338601             A                      intron_variant      MODIFIER
# 1552875             C                 3_prime_UTR_variant      MODIFIER
# 1106380             A                      intron_variant      MODIFIER
# 3588076             G                      intron_variant      MODIFIER
#
#           ANN[*].GENE ANN[*].FEATURE  ANN[*].BIOTYPE  \
# 465047         RBFOX1     transcript  protein_coding
# 569331   LOC101017094     transcript      pseudogene
# 4130166             .              .               .
# 2632912             .              .               .
# 3159509         DAPK2     transcript  protein_coding
# 44416               .              .               .
# 3296803          IFI6     transcript  protein_coding
# 1863842         USP34     transcript  protein_coding
# 4052749         PDIA6     transcript  protein_coding
# 3562254         SSRP1     transcript  protein_coding
# 1119047        ZNF880     transcript  protein_coding
# 3212662         NOC3L     transcript  protein_coding
# 2481419             .              .               .
# 1816534        KCNAB2     transcript  protein_coding
# 519898           TRIO     transcript  protein_coding
# 1593452         CEP89     transcript  protein_coding
# 973503           AFDN     transcript  protein_coding
# 225809          INTS9     transcript  protein_coding
# 2203859         ZBTB4     transcript  protein_coding
# 3230989       PITPNC1     transcript  protein_coding
# 3885006         NADK2     transcript  protein_coding
# 495777   LOC101019888     transcript      pseudogene
# 481853          RAB20     transcript  protein_coding
# 2405964         TNNT3     transcript  protein_coding
# 529606         TRIM41     transcript      pseudogene
# 2604441          ARSK     transcript  protein_coding
# 259048          TAFA2     transcript      pseudogene
# 1913041         ABCC8     transcript  protein_coding
# 2253257         ABCB4     transcript  protein_coding
# 3117727          COX2     transcript  protein_coding
# 3140888         SORL1     transcript  protein_coding
# 367555      EEF1AKMT1     transcript      pseudogene
# 3641510       RAPGEF5     transcript  protein_coding
# 2293143        CD2BP2     transcript  protein_coding
# 4034836         ARRB1     transcript  protein_coding
# 1239734  LOC101024909     transcript      pseudogene
# 4187300          FMO5     transcript  protein_coding
# 550503   LOC103883809     transcript      pseudogene
# 3196486          RBM7     transcript  protein_coding
# 2825721         AP5M1     transcript      pseudogene
# 1342249             .              .               .
# 2830545      SLC22A15     transcript      pseudogene
# 1056991        NSFL1C     transcript  protein_coding
# 2647263        NDUFB8     transcript  protein_coding
# 184537          SOGA3     transcript  protein_coding
# 2167797       RANBP3L     transcript  protein_coding
# 2338601        TVP23A     transcript  protein_coding
# 1552875  LOC108582527     transcript  protein_coding
# 1106380         TUBB6     transcript  protein_coding
# 3588076         MCF2L     transcript  protein_coding
#
#                                   uq_id      phase_info  \
# 465047    VIC:ZT16:NC_044993.1:66599840  GT:AD:DP:GQ:PS
# 569331       HEA:ZT8:NC_044988.1:132065  GT:AD:DP:GQ:PS
# 4130166   KIC:ZT18:NC_044994.1:66356799  GT:AD:DP:GQ:PS
# 2632912   ILE:ZT8:NC_044981.1:126429485  GT:AD:DP:GQ:PS
# 3159509  ILE:ZT14:NC_044982.1:125448073  GT:AD:DP:GQ:PS
# 44416    SPL:ZT18:NC_044976.1:204452726  GT:AD:DP:GQ:PS
# 3296803   ILE:ZT10:NC_044976.1:25997598  GT:AD:DP:GQ:PS
# 1863842    VIC:ZT0:NC_044989.1:61802274  GT:AD:DP:GQ:PS
# 4052749   VIC:ZT22:NC_044989.1:10612341  GT:AD:DP:GQ:PS
# 3562254   LUN:ZT8:NC_044987.1:107667494  GT:AD:DP:GQ:PS
# 1119047     SPL:ZT6:NC_044995.1:7066261  GT:AD:DP:GQ:PS
# 3212662    THA:ZT6:NC_044986.1:39513814  GT:AD:DP:GQ:PS
# 2481419   WAT:ZT18:NC_044986.1:14229205  GT:AD:DP:GQ:PS
# 1816534     VIC:ZT2:NC_044976.1:4878202  GT:AD:DP:GQ:PS
# 519898    KIC:ZT20:NC_044980.1:13848677  GT:AD:DP:GQ:PS
# 1593452   WAT:ZT22:NC_044995.1:23427593  GT:AD:DP:GQ:PS
# 973503   ILE:ZT20:NC_044981.1:164488731  GT:AD:DP:GQ:PS
# 225809     VIC:ZT4:NC_044983.1:26988603  GT:AD:DP:GQ:PS
# 2203859     PAN:ZT6:NC_044992.1:6995089  GT:AD:DP:GQ:PS
# 3230989    SPL:ZT8:NC_044992.1:59630242  GT:AD:DP:GQ:PS
# 3885006    LUN:ZT4:NC_044980.1:35001492  GT:AD:DP:GQ:PS
# 495777    HIP:ZT22:NC_044986.1:35705885  GT:AD:DP:GQ:PS
# 1593452   0|1:16,15:31:99:17038202
# 973503    0|1:21,19:40:99:24413645
# 225809    1|0:20,21:41:99:16873585
# 2203859    1|0:27,18:45:99:6685559
# 3230989   0|1:23,14:38:99:25472635
# 3885006   1|0:29,26:55:99:33867891
# 495777    1|0:15,28:43:99:35626347
# 481853    1|0:26,24:50:99:87588508
# 2405964  0|1:54,24:78:99:121838746
# 529606   1|0:12,22:34:99:173592750
# 2604441   1|0:20,16:36:99:55490631
# 259048    1|0:16,19:35:99:42539009
# 1913041    1|0:23,30:53:99:1785340
# 2253257   0|1:10,13:23:99:46711324
# 3117727         0|1:7,9:16:99:7652
# 3140888   0|1:21,15:36:99:11917675
# 367555       0|1:29,33:62:99:75468
# 3641510   1|0:16,23:39:99:91398298
# 2293143   0|1:21,22:43:99:45734483
# 4034836   0|1:21,23:44:99:57780625
# 1239734  0|1:28,13:41:99:129753724
# 4187300        1|0:26,16:42:99:907
# 550503    0|1:24,21:45:99:74083662
# 3196486   1|0:31,16:47:99:19738063
# 2825721   0|1:15,20:35:99:44411430
# 1342249    0|1:23,23:46:99:3378955
# 2830545    0|1:19,31:50:99:3864864
# 1056991     0|1:18,15:33:99:771575
# 2647263    1|0:18,18:36:99:5556136
# 184537   1|0:12,17:29:99:134252209
# 2167797   0|1:20,11:31:99:34542779
# 2338601   1|0:19,18:37:99:63124665
# 1552875   0|1:17,18:35:99:53976093
# 1106380     1|0:13,16:29:99:602809
# 3588076   1|0:26,28:54:99:89771796

# %%
## function to check whether the SNV is phased
def is_phased(x):
    if pd.isnull(x):
        return "no_data"
    else:
        x = x.split(":")
        if "PS" in x:
            return 'phased'
        else:
            return 'not_phased'

# %%
## label each SNV as phased or unphased
dat['is_phased'] = dat['phase_info'].parallel_apply(is_phased)
dat['is_phased'].value_counts()
####################################
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=5986177), Label(value='0 / 5986177…
# phased        47751036
# not_phased      138377
# Name: is_phased, dtype: int64

# %%
## Get phase ID for each SNV
def get_phased_block_id(x: pd.Series):
    if x['is_phased'] == 'no_data':
        return 'no_data'
    else:
        phase_data = {i:j for i, j in zip(x['phase_info'].split(":"), x['phase_dat'].split(":"))}
        if 'PS' in phase_data:
            return phase_data['PS']
        else:
            return 'not_phased'

# %%
dat['phase_id'] = dat.parallel_apply(get_phased_block_id, axis=1)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=5986177), Label(value='0 / 5986177…

# %%
def compute_homoloBias(x: pd.Series):
    if x['is_phased']=="no_data":
        return "no_data"
    else:
        phase_data = {i:j for i, j in zip(x['phase_info'].split(":"), x['phase_dat'].split(":"))}
        if 'PS' not in phase_data:
            return np.nan
        elif phase_data['GT'] == '0|1':
            return x['refBias']
        elif phase_data['GT'] == '1|0':
            return 1-x['refBias']
        else:
            raise ValueError

# %%
dat['homologBias'] = dat.parallel_apply(compute_homoloBias, axis=1)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=5986177), Label(value='0 / 5986177…

# %%
dat.to_parquet("./data_files/concatenated_data/gatk_all_samples_concatenated_annt_added_multiline_dupes_dropped_phase_added.parquet")
